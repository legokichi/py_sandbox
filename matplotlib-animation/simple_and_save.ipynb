# %% [markdown]
# * https://teratail.com/questions/113044
# * https://qiita.com/fiftystorm36/items/9af9d79353f31c75c9de
# * https://qiita.com/Tatejimaru137/items/6083e2e3a4e618da6274

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib import animation

def create_circle():
    circle = plt.Circle((0,0), radius=0.15)
    return circle

def update_radius(i, circle):
    circle.set_radius(i*0.5)
    return circle,

fig = plt.figure(1)
ax = plt.axes(xlim=(-10,10), ylim=(-10,10))
ax.set_aspect('equal')
circle = create_circle()
ax.add_artist(circle)
anim = animation.FuncAnimation(fig, update_radius, fargs=(circle,),
                               frames=30, interval=50)

plt.title('Simple Circle Animation')


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 保存
anim.save('anim.gif', writer='imagemagick', fps=4)
anim.save('anim.mp4', writer='ffmpeg', fps=4)
anim.save('anim.webm', writer='ffmpeg', fps=4)
